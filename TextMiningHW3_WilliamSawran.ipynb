# %% [markdown]
# <a href="https://colab.research.google.com/github/WilliamSawran/ABC/blob/master/TextMiningHW3_WilliamSawran.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/'My Drive'/HW3/HW3/
# !ls
# Out:
# /content/drive/My Drive/HW3/HW3
# Human_Summaries  HW3.pdf  pyrouge  System_Summaries

# %%
# !apt install cpanminus

# %%
# !!apt-get install libxml-dom-xpath-perl

# %%
# !git clone https://github.com/summanlp/evaluation

# %%
# %%bash
# export ROUGE_EVAL_HOME="/content/drive/My Drive/HW3/HW3/pyrouge/evaluation/ROUGE-RELEASE-1.5.5/data/"

# %%
# %cd /content/drive/My Drive/HW3/HW3/pyrouge/evaluation/ROUGE-RELEASE-1.5.5
# Out:
# /content/drive/My Drive/HW3/HW3/pyrouge/evaluation/ROUGE-RELEASE-1.5.5

# %%
# !chmod 777 ROUGE-1.5.5.pl

# %%
# Test Perl-implemented ROUGE toolkit for functionlity
# !perl runROUGE-test.pl

# %%
# !apt-get install synaptic

# %%
# !apt-get install libxml-libxml-perl

# %%
# install missing dependency
# !apt install libxml-parser-perl

# %%
# !pwd
# Out:
# /content/drive/My Drive/HW3/HW3/pyrouge/pyrouge

# %%
# %cd /content/drive/My Drive/HW3/HW3/pyrouge
# !pwd
# Out:
# /content/drive/My Drive/HW3/HW3/pyrouge
# /content/drive/My Drive/HW3/HW3/pyrouge

# %%
# !git clone https://github.com/bheinzerling/pyrouge

# %%
# !python setup.py install

# %%
# %cd pyrouge
# Out:
# /content/drive/My Drive/HW3/HW3/pyrouge

# %%
from pyrouge import Rouge155
# !pyrouge_set_rouge_path '/content/drive/MyDrive/HW3/HW3/pyrouge/evaluation/ROUGE-RELEASE-1.5.5'
# Out:
# 2021-11-12 00:23:26,631 [MainThread  ] [INFO ]  Set ROUGE home directory to /content/drive/MyDrive/HW3/HW3/pyrouge/evaluation/ROUGE-RELEASE-1.5.5.

# %%
# Test Perl-implemented ROUGE toolkit for functionlity
# !python -m pyrouge.test

# %%
from pyrouge import Rouge155
r = Rouge155()
# set directories
r.system_dir = '/content/drive/MyDrive/HW3/HW3/System_Summaries/DPP'
r.model_dir = '/content/drive/MyDrive/HW3/HW3/Human_Summaries/eval'

# define the patterns
r.system_filename_pattern = 'd(\d+)t.DPP'
r.model_filename_pattern = 'D#ID#.M.100.T.[A-Z]'

# use default parameters to run the evaluation
output = r.convert_and_evaluate()
print(output)
output_dict = r.output_to_dict(output)
# Out:
# 2021-11-12 00:24:54,619 [MainThread  ] [INFO ]  Writing summaries.
# 2021-11-12 00:24:54,622 [MainThread  ] [INFO ]  Processing summaries. Saving system files to /tmp/tmp0_cz2i_5/system and model files to /tmp/tmp0_cz2i_5/model.
# 2021-11-12 00:24:54,624 [MainThread  ] [INFO ]  Processing files in /content/drive/MyDrive/HW3/HW3/System_Summaries/DPP.
# 2021-11-12 00:24:55,010 [MainThread  ] [INFO ]  Processing d31043t.DPP.
# 2021-11-12 00:24:55,135 [MainThread  ] [INFO ]  Processing d30042t.DPP.
# 2021-11-12 00:25:02,248 [MainThread  ] [INFO ]  Processing d31038t.DPP.
# 2021-11-12 00:25:02,375 [MainThread  ] [INFO ]  Processing d30015t.DPP.
# 2021-11-12 00:25:02,520 [MainThread  ] [INFO ]  Processing d30003t.DPP.
# 2021-11-12 00:25:02,713 [MainThread  ] [INFO ]  Processing d31022t.DPP.
# 2021-11-12 00:25:02,859 [MainThread  ] [INFO ]  Processing d30059t.DPP.
# 2021-11-12 00:25:03,011 [MainThread  ] [INFO ]  Processing d30034t.DPP.
# ...

# %%
from pyrouge import Rouge155
r = Rouge155()
# set directories
r.system_dir = '/content/drive/MyDrive/HW3/HW3/System_Summaries/Submodular'
r.model_dir = '/content/drive/MyDrive/HW3/HW3/Human_Summaries/eval'

# define the patterns
r.system_filename_pattern = 'd(\d+)t.Submodular'
r.model_filename_pattern = 'D#ID#.M.100.T.[A-Z]'

# use default parameters to run the evaluation
output = r.convert_and_evaluate()
print(output)
output_dict = r.output_to_dict(output)
# Out:
# 2021-11-12 00:49:05,599 [MainThread  ] [INFO ]  Writing summaries.
# 2021-11-12 00:49:05,604 [MainThread  ] [INFO ]  Processing summaries. Saving system files to /tmp/tmp92t6ohm7/system and model files to /tmp/tmp92t6ohm7/model.
# 2021-11-12 00:49:05,605 [MainThread  ] [INFO ]  Processing files in /content/drive/MyDrive/HW3/HW3/System_Summaries/Submodular.
# 2021-11-12 00:49:06,050 [MainThread  ] [INFO ]  Processing d30051t.Submodular.
# 2021-11-12 00:49:06,191 [MainThread  ] [INFO ]  Processing d31038t.Submodular.
# 2021-11-12 00:49:06,339 [MainThread  ] [INFO ]  Processing d30006t.Submodular.
# 2021-11-12 00:49:06,474 [MainThread  ] [INFO ]  Processing d30028t.Submodular.
# 2021-11-12 00:49:06,612 [MainThread  ] [INFO ]  Processing d31031t.Submodular.
# 2021-11-12 00:49:06,757 [MainThread  ] [INFO ]  Processing d30044t.Submodular.
# 2021-11-12 00:49:06,913 [MainThread  ] [INFO ]  Processing d30034t.Submodular.
# ...

# %%
from pyrouge import Rouge155
r = Rouge155()
# set directories
r.system_dir = '/content/drive/MyDrive/HW3/HW3/System_Summaries/LexRank'
r.model_dir = '/content/drive/MyDrive/HW3/HW3/Human_Summaries/eval'

# define the patterns
r.system_filename_pattern = 'd(\d+)t.LexRank'
r.model_filename_pattern = 'D#ID#.M.100.T.[A-Z]'

# use default parameters to run the evaluation
output = r.convert_and_evaluate()
print(output)
output_dict = r.output_to_dict(output)
# Out:
# 2021-11-12 00:57:20,825 [MainThread  ] [INFO ]  Writing summaries.
# 2021-11-12 00:57:20,829 [MainThread  ] [INFO ]  Processing summaries. Saving system files to /tmp/tmpnsiztmpu/system and model files to /tmp/tmpnsiztmpu/model.
# 2021-11-12 00:57:20,833 [MainThread  ] [INFO ]  Processing files in /content/drive/MyDrive/HW3/HW3/System_Summaries/LexRank.
# 2021-11-12 00:57:21,385 [MainThread  ] [INFO ]  Processing d30022t.LexRank.
# 2021-11-12 00:57:21,589 [MainThread  ] [INFO ]  Processing d30055t.LexRank.
# 2021-11-12 00:57:21,729 [MainThread  ] [INFO ]  Processing d30028t.LexRank.
# 2021-11-12 00:57:21,863 [MainThread  ] [INFO ]  Processing d30029t.LexRank.
# 2021-11-12 00:57:22,147 [MainThread  ] [INFO ]  Processing d30017t.LexRank.
# 2021-11-12 00:57:22,293 [MainThread  ] [INFO ]  Processing d30034t.LexRank.
# 2021-11-12 00:57:22,452 [MainThread  ] [INFO ]  Processing d31009t.LexRank.
# 2021-11-12 00:57:22,600 [MainThread  ] [INFO ]  Processing d31008t.LexRank.
# ...

# %%
from pyrouge import Rouge155
r = Rouge155()
# set directories
r.system_dir = '/content/drive/MyDrive/HW3/HW3/System_Summaries/ICSISumm'
r.model_dir = '/content/drive/MyDrive/HW3/HW3/Human_Summaries/eval'

# define the patterns
r.system_filename_pattern = 'd(\d+)t.ICSISumm'
r.model_filename_pattern = 'D#ID#.M.100.T.[A-Z]'

# use default parameters to run the evaluation
output = r.convert_and_evaluate()
print(output)
output_dict = r.output_to_dict(output)
# Out:
# 2021-11-12 01:00:50,905 [MainThread  ] [INFO ]  Writing summaries.
# 2021-11-12 01:00:50,909 [MainThread  ] [INFO ]  Processing summaries. Saving system files to /tmp/tmpu8b5rc8y/system and model files to /tmp/tmpu8b5rc8y/model.
# 2021-11-12 01:00:50,912 [MainThread  ] [INFO ]  Processing files in /content/drive/MyDrive/HW3/HW3/System_Summaries/ICSISumm.
# 2021-11-12 01:00:51,513 [MainThread  ] [INFO ]  Processing d30010t.ICSISumm.
# 2021-11-12 01:00:51,632 [MainThread  ] [INFO ]  Processing d30031t.ICSISumm.
# 2021-11-12 01:00:51,785 [MainThread  ] [INFO ]  Processing d30046t.ICSISumm.
# 2021-11-12 01:00:51,922 [MainThread  ] [INFO ]  Processing d30028t.ICSISumm.
# 2021-11-12 01:00:52,100 [MainThread  ] [INFO ]  Processing d31031t.ICSISumm.
# 2021-11-12 01:00:52,334 [MainThread  ] [INFO ]  Processing d30037t.ICSISumm.
# 2021-11-12 01:00:52,499 [MainThread  ] [INFO ]  Processing d30059t.ICSISumm.
# 2021-11-12 01:00:52,636 [MainThread  ] [INFO ]  Processing d30002t.ICSISumm.
# ...

# %%
from pyrouge import Rouge155
r = Rouge155()
# set directories
r.system_dir = '/content/drive/MyDrive/HW3/HW3/System_Summaries/Centroid'
r.model_dir = '/content/drive/MyDrive/HW3/HW3/Human_Summaries/eval'

# define the patterns
r.system_filename_pattern = 'd(\d+)t.Centroid'
r.model_filename_pattern = 'D#ID#.M.100.T.[A-Z]'

# use default parameters to run the evaluation
output = r.convert_and_evaluate()
print(output)
output_dict = r.output_to_dict(output)
# Out:
# 2021-11-12 01:04:41,122 [MainThread  ] [INFO ]  Writing summaries.
# 2021-11-12 01:04:41,126 [MainThread  ] [INFO ]  Processing summaries. Saving system files to /tmp/tmpobu_g30x/system and model files to /tmp/tmpobu_g30x/model.
# 2021-11-12 01:04:41,129 [MainThread  ] [INFO ]  Processing files in /content/drive/MyDrive/HW3/HW3/System_Summaries/Centroid.
# 2021-11-12 01:04:41,775 [MainThread  ] [INFO ]  Processing d31001t.Centroid.
# 2021-11-12 01:04:41,919 [MainThread  ] [INFO ]  Processing d30007t.Centroid.
# 2021-11-12 01:04:42,108 [MainThread  ] [INFO ]  Processing d30026t.Centroid.
# 2021-11-12 01:04:42,288 [MainThread  ] [INFO ]  Processing d30048t.Centroid.
# 2021-11-12 01:04:42,413 [MainThread  ] [INFO ]  Processing d30051t.Centroid.
# 2021-11-12 01:04:42,578 [MainThread  ] [INFO ]  Processing d31043t.Centroid.
# 2021-11-12 01:04:42,742 [MainThread  ] [INFO ]  Processing d30045t.Centroid.
# 2021-11-12 01:04:42,906 [MainThread  ] [INFO ]  Processing d31026t.Centroid.
# ...
